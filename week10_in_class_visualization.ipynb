# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import time
import networkx 
from networkx import nx

# %%
# !pwd
# Out:
# /Users/jinqingliang/Desktop/data 601

# %%
df = np.load("/Users/jinqingliang/Desktop/data 601/week10/netflow_day_02_1E6rows.pkl", allow_pickle=True)

# %%
df.describe()
# Out:
#                  Time      Duration        Protocol    SrcPackets  \
# count  1000000.000000  1.000000e+06  1000000.000000  1.000000e+06
# mean    120681.206199  9.263692e+05        9.835121  2.817749e+05
# std        223.686539  1.443185e+06        6.421107  1.667190e+07
# min     118781.000000  0.000000e+00        1.000000  0.000000e+00
# 25%     120559.000000  6.100500e+04        6.000000  5.270000e+02
# 50%     120663.000000  3.764260e+05        6.000000  5.753000e+03
# 75%     120898.000000  9.324350e+05       17.000000  3.368300e+04
# max     120981.000000  7.655151e+06       17.000000  2.396174e+09
#
#          DstPackets      SrcBytes      DstBytes
# count  1.000000e+06  1.000000e+06  1.000000e+06
# mean   2.593367e+05  8.313542e+07  8.503756e+07
# std    1.981153e+07  3.140737e+09  4.350704e+09
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  4.229100e+04  0.000000e+00
# 50%    0.000000e+00  9.995940e+05  0.000000e+00
# ...

# %%
df
# Out:
#           Time  Duration   SrcDevice   DstDevice  Protocol    SrcPort  \
# 0       118781      5580  Comp364445  Comp547245        17  Port05507
# 1       118783      6976  Comp450942  Comp829338         6  Port03137
# 2       118785     14178    IP564116  Comp141988        17       5060
# 3       118785     28147    IP564116  Comp141988        17       5060
# 4       118785     48507    IP564116  Comp141988        17       5060
# ...        ...       ...         ...         ...       ...        ...
# 999995  120981     99232  Comp916575  Comp186884         6  Port80849
# 999996  120981     99233  Comp522078  Comp303229         6  Port26404
# 999997  120981     99246  Comp742609  Comp186884         6  Port09866
# 999998  120981     99249  Comp883534  Comp395285         6  Port62088
# 999999  120981     99251  Comp675561  Comp186884         6  Port33913
#
#           DstPort  SrcPackets  DstPackets  SrcBytes    DstBytes
# ...

# %%
df.shape
# Out:
# (1000000, 11)

# %%
df.head()
# Out:
#      Time  Duration   SrcDevice   DstDevice  Protocol    SrcPort    DstPort  \
# 0  118781      5580  Comp364445  Comp547245        17  Port05507  Port46272
# 1  118783      6976  Comp450942  Comp829338         6  Port03137        445
# 2  118785     14178    IP564116  Comp141988        17       5060       5060
# 3  118785     28147    IP564116  Comp141988        17       5060       5060
# 4  118785     48507    IP564116  Comp141988        17       5060       5060
#
#    SrcPackets  DstPackets  SrcBytes    DstBytes
# 0           0      755065         0  1042329018
# 1        1665        1108    300810      250408
# 2        1866           0   1477041           0
# 3        3326           0   2656305           0
# 4        5423           0   4388449           0

# %%
try:
    G.clear()
except NameError:
    pass

# %%
G = nx.from_pandas_edgelist(df[0:10],'SrcDevice','DstDevice','Duration')

# %%
G.number_of_nodes()
# Out:
# 6

# %%
nx.draw(G, with_labels = False, node_size = 100)
plt.show()
# Out:
# /Users/jinqingliang/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
nx.draw(G, with_labels=False,node_size=100,pos = nx.circular_layout(G))
plt.show()

# %%
pos = nx.spring_layout(G)
nx.draw(G,with_labels=True)
nx.draw_networkx_edge_labels(G,pos=pos,with_labels=True)
_=plt.axis('off')

# %%
G = nx.from_pandas_edgelist(df[0:100],'SrcDevice','DstDevice','Duration')

# %%
G.number_of_nodes()
# Out:
# 42

# %%
nx.draw(G, with_labels = False, node_size = 100)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:1000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
nx.draw(G, with_labels = False, node_size = 20)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:10000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
nx.draw(G, with_labels = False, node_size = 10)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:50000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
nx.draw(G, with_labels = False, node_size = 10)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:20000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
nx.draw(G, with_labels = False, node_size = 10)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:5000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
plt.figure(figsize=(20,20))
nx.set_node_attributes(G, 'Duration', 'val')
colors = [i/len(G.nodes) for i in range(len(G.nodes))]
nx.draw(G, with_labels = False, node_color = colors, node_size = 25, cmap = plt.cm.coolwarm)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:10000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
plt.figure(figsize=(20,20))
nx.set_node_attributes(G, 'Duration', 'val')
colors = [i/len(G.nodes) for i in range(len(G.nodes))]
nx.draw(G, with_labels = False, node_color = colors, node_size = 25, cmap = plt.cm.coolwarm)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:20000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
plt.figure(figsize=(20,20))
nx.set_node_attributes(G, 'Duration', 'val')
colors = [i/len(G.nodes) for i in range(len(G.nodes))]
nx.draw(G, with_labels = False, node_color = colors, node_size = 25, cmap = plt.cm.coolwarm)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:20000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
plt.figure(figsize=(20,20))
nx.set_node_attributes(G, 'Duration', 'val')
colors = [i/len(G.nodes) for i in range(len(G.nodes))]
nx.draw(G, with_labels = False, node_color = colors, node_size = 20, cmap = plt.cm.coolwarm)
plt.show()

# %%
G = nx.from_pandas_edgelist(df[0:30000],'SrcDevice','DstDevice','Duration')
G.number_of_nodes()
plt.figure(figsize=(20,20))
nx.set_node_attributes(G, 'Duration', 'val')
colors = [i/len(G.nodes) for i in range(len(G.nodes))]
nx.draw(G, with_labels = False, node_color = colors, node_size = 25, cmap = plt.cm.coolwarm)
plt.show()

# %%
G.number_of_nodes()
# Out:
# 3628
